# %%
# !pip install signatory
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for signatory: filename=signatory-1.2.6.1.9.0-cp312-cp312-linux_x86_64.whl size=13144662 sha256=03ac591bad2bec8161c406c1ce7d81828259acda90a9e3e33281c1fca745e6e6
#   Stored in directory: /root/.cache/pip/wheels/ea/18/f4/25aee915ecc6b29d1a54962265ca510a889b7ea71905f446b5
# Successfully built signatory
# ...
